# %%
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.patches as mpatches

# %%
import plotly.express as px
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
conversion = pd.read_excel('conversion_ of_three.xlsx', names=['catalisador','percentage'])

# %%
conversion
# Out:
#       catalisador percentage
# 0        130-5-In         98
# 1        130-8-In         98
# 2     120-65-In-1         98
# 3     120-65-In-2      Falta
# 4     120-65-In-3      Falta
# 5        110-5-In         86
# 6        110-8-In         89
# 7        130-5-Sn         98
# 8        130-8-Sn         98
# 9     120-65-Sn-1         92
# 10    120-65-Sn-2      Falta
# 11    120-65-Sn-3      Falta
# 12       110-5-Sn         96
# 13       110-8-Sn         95
# 14       130-5-Cu         98
# 15       130-8-Cu         90
# 16    120-65-Cu-1         68
# 17    120-65-Cu-2      Falta
# 18    120-65-Cu-3      Falta
# 19       110-5-Cu         85
# 20       110-8-Cu         68
# 21    130-5-DBTDL         98
# 22     130-8-DBTL         98
# 23  120-65-DBTL-1      Falta
# 24  120-65-DBTL-2      Falta
# 25  120-65-DBTL-3      Falta
# 26    110-5-DBTDL         98
# 27    110-8-DBTDL         98

# %%
conversion['catalisador']
# Out:
# 0          130-5-In
# 1          130-8-In
# 2       120-65-In-1
# 3       120-65-In-2
# 4       120-65-In-3
# 5          110-5-In
# 6          110-8-In
# 7          130-5-Sn
# 8          130-8-Sn
# 9       120-65-Sn-1
# 10      120-65-Sn-2
# 11      120-65-Sn-3
# 12         110-5-Sn
# 13         110-8-Sn
# 14         130-5-Cu
# 15         130-8-Cu
# 16      120-65-Cu-1
# 17      120-65-Cu-2
# 18      120-65-Cu-3
# 19         110-5-Cu
# 20         110-8-Cu
# 21      130-5-DBTDL
# 22       130-8-DBTL
# 23    120-65-DBTL-1
# 24    120-65-DBTL-2
# 25    120-65-DBTL-3
# 26      110-5-DBTDL
# 27      110-8-DBTDL
# Name: catalisador, dtype: object

# %%
conversion_percentage = pd.to_numeric(conversion['percentage'], errors='coerce')

# %%
plt.figure(figsize=(20,16))

plt.bar(conversion['catalisador'], conversion_percentage, label='')
plt.xlabel('Catalisadores', size= 30)
plt.ylabel('Taxa de conversão em %', size= 30)
#red_patch = mpatches.Patch(color='red', label='The red data')
#plt.legend(loc='upper left', frameon=False)
plt.legend('')
plt.xticks(size= 20) #0.5)
plt.yticks(np.arange(0,110,step=5), size= 20) #0.5))
#plt.set_title('Conversão dos catalisadores')
plt.xticks(rotation=45)


#plt.savefig("conversao.jpg", format='jpg', dpi=1200)


plt.tight_layout()
plt.show()
